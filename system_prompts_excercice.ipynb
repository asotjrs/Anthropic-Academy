# %% [markdown]
# <a href="https://colab.research.google.com/github/asotjrs/Anthropic-Academy/blob/main/system_prompts_excercice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# loading env variable
from dotenv import load_dotenv
load_dotenv()

# Creating the API Client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
#Building helper functions
def add_user_message(messages,text):
  user_message={"role":"user","content":text}
  messages.append(user_message)

def add_assistant_message(messages,text):
  assistant_message={"role":"assistant","content":text}
  messages.append(assistant_message)

def chat(messages, system=None):
  params = {
            "model":model,
            "max_token":1000,
             "messages":messages
            }
  if system:
    params["system"] = system
  message= client.messages.create(**params)
  return message.content[0].text

# %%
messages=[]
system="""
You are andrej karpathy,
a genius in simplifying python code,
you even recently created a script for training a gpt in 200 lines which is extraordinary,
 you write code as simple as possible, no comments, no explanations, just code. efficient useful straight to the point minimal code
"""
# This was suprising i know Haha
add_user_message(messages,"write a python function to check for fuplicates in a string")
answer = chat(messages,system)
print(answer)

# %% [markdown]
# this will return:
#
# ```
# def has_duplicates(s):
#     return len(set(s)) < len(s)
# ```
# instead of a very long explained comments added to code
