# %% [markdown]
# <a href="https://colab.research.google.com/github/asotjrs/Anthropic-Academy/blob/main/Making-a-Request.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Following along with Anthropic Academy lectures:
# ##Course : Building with the Claude API.
# ###Lecture: Making a request

# %%
# @title installing necessary packages
# %pip install anthropic python-dotenv

# %%
# loading env variable
from dotenv import load_dotenv
load_dotenv()

# Creating the API Client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
# Making my first request to Claude
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "What is quantum computing? Answer in one sentence"
        }
    ]
)

# %% [markdown]
# ##Ooops I don't really have an API KEY , they are paid, i will get back to this maybe when i can pay for it
