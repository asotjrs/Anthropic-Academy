# %% [markdown]
# <a href="https://colab.research.google.com/github/asotjrs/Anthropic-Academy/blob/main/Multi_Turn_Conversation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### We need to manually maintain  a list of all messages in out code  then send the complete message history with every request

# %%
#Building helper functions
def add_user_message(messages,text):
  user_message={"role":"user","content":text}
  messages.append(user_message)

def add_assistant_message(messages,text):
  assistant_message={"role":"assistant","content":text}
  messages.append(assistant_message)

def chat(messages):
  message= client.messages.create(
      model=model,
      max_token=1000,
      messages=messages)
  return message.content[0].text

# %% [markdown]
# ###Putting it all together

# %%
#Start with an empty lessage list
messages=[]

#Add the initial user question
add_user_message(messages,"Define Quantum computing in one sentence")

#Get Claude's response
response=chat(messages)

#Add Claude's response to the conversation history
add_assistant_message(messages,response)

#Add follow-up question
add_user_message(messages,"Can you give me an example?")

#Get Claude's final response with full context
response=chat(messages)

# %% [markdown]
# ###Now Claude will understand that Asking for an example refers to expanding the Quantum computing definition
